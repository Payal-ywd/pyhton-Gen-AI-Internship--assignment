# %%
# Problem 1: Smart Light Controller

class SmartLight:
    def __init__(self, name):
        self.name = name

    def turn_on(self):
        print(self.name, "is ON")

    def turn_off(self):
        print(self.name, "is OFF")


light_name = input("Light Name: ")
action = input("Action (ON/OFF): ")

light = SmartLight(light_name)

if action.upper() == "ON":
    light.turn_on()
else:
    light.turn_off()
# Out:
# Light Name:  blue
# Action (ON/OFF):  on
# blue is ON

# %%
# Problem 2: Employee ID Card System

class Employee:
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department

    def display(self):
        print("Employee ID Card")
        print("Name:", self.name)
        print("ID:", self.emp_id)
        print("Department:", self.department)


name = input("Employee Name: ")
emp_id = input("Employee ID: ")
dept = input("Department: ")

emp = Employee(name, emp_id, dept)
emp.display()
# Out:
# Employee Name:  Payal
# Employee ID:  24DCCS1101022
# Department:  cyber security
# Employee ID Card
# Name: Payal
# ID: 24DCCS1101022
# Department: cyber security

# %%
# Problem 3: Mobile Contact Record

class Contact:
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def display(self):
        print("Contact Saved")
        print("Name:", self.name)
        print("Phone:", self.phone)


name = input("Contact Name: ")
phone = input("Phone Number: ")

c = Contact(name, phone)
c.display()
# Out:
# Contact Name:  Payal Yachwad
# Phone Number:  7378887391
# Contact Saved
# Name: Payal Yachwad
# Phone: 7378887391

# %%
# Problem 4: Product Price Tag Generator

class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def display(self):
        print("Product:", self.name)
        print("Price: ₹" + str(self.price))


name = input("Product Name: ")
price = input("Price: ")

p = Product(name, price)
p.display()
# Out:
# Product Name:  Baggy jeans
# Price:  1500
# Product: Baggy jeans
# Price: ₹1500

# %%
# Problem 5: Movie Rating Display System

class Movie:
    def __init__(self, name, rating):
        self.name = name
        self.rating = rating

    def display(self):
        print("Movie:", self.name)
        print("Rating:", self.rating, "/ 5")


name = input("Movie Name: ")
rating = input("Rating: ")

m = Movie(name, rating)
m.display()
# Out:
# Movie Name:  kerala story
# Rating:  3
# Movie: kerala story
# Rating: 3 / 5

# %%
# Problem 6: Delivery Address Manager

class Delivery:
    def __init__(self, customer, address):
        self.customer = customer
        self.address = address

    def display(self):
        print("Delivery Details")
        print("Customer:", self.customer)
        print("Address:", self.address)


customer = input("Customer Name: ")
address = input("Address: ")

d = Delivery(customer, address)
d.display()
# Out:
# Customer Name:  Jijai Gunale
# Address:  Pune
# Delivery Details
# Customer: Jijai Gunale
# Address: Pune
